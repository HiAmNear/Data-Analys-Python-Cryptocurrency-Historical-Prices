# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline
import matplotlib
from matplotlib.colors import LinearSegmentedColormap
# For reading stock data from yahoo
from pandas_datareader.data import DataReader
# For time stamps
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
Aave = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Aave.csv')
BinanceCoin = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_BinanceCoin.csv')
Bitcoin = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Bitcoin.csv')
Cardano = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Cardano.csv')
ChainLink = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_ChainLink.csv')
Cosmos = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Cosmos.csv')
CryptocomCoin = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_CryptocomCoin.csv')
Dogecoin = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Dogecoin.csv')
EOS = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_EOS.csv')
Ethereum = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Ethereum.csv')
Iota = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Iota.csv')
Litecoin = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Litecoin.csv')
Monero = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Monero.csv')
NEM = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_NEM.csv')
Polkadot = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Polkadot.csv')
Solana = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Solana.csv')
Stellar = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Stellar.csv')
Tether = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Tether.csv')
Tron = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Tron.csv')
Uniswap = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_Uniswap.csv')
USDCoin = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_USDCoin.csv')
WrappedBitcoin = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_WrappedBitcoin.csv')
XRP = pd.read_csv('/content/drive/MyDrive/Cryptocurrency Historical Prices Dataset/coin_XRP.csv')

# %%
print("Aave")
Aave.head()
# Out:
# Aave
#    SNo  Name Symbol                 Date       High        Low       Open  \
# 0    1  Aave   AAVE  2020-10-05 23:59:59  55.112358  49.787900  52.675035
# 1    2  Aave   AAVE  2020-10-06 23:59:59  53.402270  40.734578  53.291969
# 2    3  Aave   AAVE  2020-10-07 23:59:59  42.408314  35.970690  42.399947
# 3    4  Aave   AAVE  2020-10-08 23:59:59  44.902511  36.696057  39.885262
# 4    5  Aave   AAVE  2020-10-09 23:59:59  47.569533  43.291776  43.764463
#
#        Close        Volume     Marketcap
# 0  53.219243  0.000000e+00  8.912813e+07
# 1  42.401599  5.830915e+05  7.101144e+07
# 2  40.083976  6.828342e+05  6.713004e+07
# 3  43.764463  1.658817e+06  2.202651e+08
# 4  46.817744  8.155377e+05  2.356322e+08

# %%
print("BinanceCoin")
BinanceCoin.head()
# Out:
# BinanceCoin
#    SNo          Name Symbol                 Date      High       Low  \
# 0    1  Binance Coin    BNB  2017-07-26 23:59:59  0.109013  0.099266
# 1    2  Binance Coin    BNB  2017-07-27 23:59:59  0.108479  0.100888
# 2    3  Binance Coin    BNB  2017-07-28 23:59:59  0.109019  0.101473
# 3    4  Binance Coin    BNB  2017-07-29 23:59:59  0.111264  0.101108
# 4    5  Binance Coin    BNB  2017-07-30 23:59:59  0.108138  0.103162
#
#        Open     Close    Volume   Marketcap
# 0  0.105893  0.105138  200395.0  10513800.0
# 1  0.105108  0.107737  344499.0  10773700.0
# 2  0.107632  0.104067  342568.0  10406700.0
# 3  0.104782  0.107811  340218.0  10781100.0
# 4  0.107935  0.106414  224261.0  10641400.0

# %%
print("Bitcoin")
Bitcoin
# Out:
# Bitcoin
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
Bitcoin.isnull().sum()
# Out:
# SNo          0
# Name         0
# Symbol       0
# Date         0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
Aave.head()
# Out:
#    SNo  Name Symbol                 Date       High        Low       Open  \
# 0    1  Aave   AAVE  2020-10-05 23:59:59  55.112358  49.787900  52.675035
# 1    2  Aave   AAVE  2020-10-06 23:59:59  53.402270  40.734578  53.291969
# 2    3  Aave   AAVE  2020-10-07 23:59:59  42.408314  35.970690  42.399947
# 3    4  Aave   AAVE  2020-10-08 23:59:59  44.902511  36.696057  39.885262
# 4    5  Aave   AAVE  2020-10-09 23:59:59  47.569533  43.291776  43.764463
#
#        Close        Volume     Marketcap
# 0  53.219243  0.000000e+00  8.912813e+07
# 1  42.401599  5.830915e+05  7.101144e+07
# 2  40.083976  6.828342e+05  6.713004e+07
# 3  43.764463  1.658817e+06  2.202651e+08
# 4  46.817744  8.155377e+05  2.356322e+08

# %%
BinanceCoin.head()
# Out:
#    SNo          Name Symbol                 Date      High       Low  \
# 0    1  Binance Coin    BNB  2017-07-26 23:59:59  0.109013  0.099266
# 1    2  Binance Coin    BNB  2017-07-27 23:59:59  0.108479  0.100888
# 2    3  Binance Coin    BNB  2017-07-28 23:59:59  0.109019  0.101473
# 3    4  Binance Coin    BNB  2017-07-29 23:59:59  0.111264  0.101108
# 4    5  Binance Coin    BNB  2017-07-30 23:59:59  0.108138  0.103162
#
#        Open     Close    Volume   Marketcap
# 0  0.105893  0.105138  200395.0  10513800.0
# 1  0.105108  0.107737  344499.0  10773700.0
# 2  0.107632  0.104067  342568.0  10406700.0
# 3  0.104782  0.107811  340218.0  10781100.0
# 4  0.107935  0.106414  224261.0  10641400.0

# %%
Bitcoin.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
Bitcoin.describe()
# Out:
#                SNo          High           Low          Open         Close  \
# count  2991.000000   2991.000000   2991.000000   2991.000000   2991.000000
# mean   1496.000000   6893.326038   6486.009539   6700.146240   6711.290443
# std     863.571653  11642.832456  10869.032130  11288.043736  11298.141921
# min       1.000000     74.561096     65.526001     68.504997     68.431000
# 25%     748.500000    436.179001    422.879486    430.445496    430.569489
# 50%    1496.000000   2387.610107   2178.500000   2269.889893   2286.409912
# 75%    2243.500000   8733.926948   8289.800459   8569.656494   8576.238715
# max    2991.000000  64863.098908  62208.964366  63523.754869  63503.457930
#
#              Volume     Marketcap
# count  2.991000e+03  2.991000e+03
# mean   1.090633e+10  1.208761e+11
# std    1.888895e+10  2.109438e+11
# min    0.000000e+00  7.784112e+08
# 25%    3.036725e+07  6.305579e+09
# 50%    9.460360e+08  3.741503e+10
# 75%    1.592015e+10  1.499957e+11
# ...

# %%
df = pd.DataFrame({'BTC': Bitcoin.Close,
                   'ETH': Ethereum .Close,
                   'LTC': Litecoin.Close})
df.head()
# Out:
#           BTC       ETH      LTC
# 0  144.539993  0.753325  4.38390
# 1  139.000000  0.701897  4.29649
# 2  116.989998  0.708448  3.80101
# 3  105.209999  1.067860  3.37198
# 4   97.750000  1.217440  3.04491

# %%
df.describe()
# Out:
#                 BTC          ETH          LTC
# count   2991.000000  2160.000000  2991.000000
# mean    6711.290443   383.910691    49.279008
# std    11298.141921   601.078766    63.240464
# min       68.431000     0.434829     1.157010
# 25%      430.569489    13.819200     3.794135
# 50%     2286.409912   198.643691    29.900200
# 75%     8576.238715   386.435272    62.025043
# max    63503.457930  4168.701049   386.450779

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
my_crypto = df
plt.figure(figsize = (12.2, 4.5))
for c in my_crypto.columns.values:
   plt.plot(my_crypto[c], label = c)
plt.title('Cryptocurrency Graph')
plt.xlabel('Days')
plt.ylabel(' Crypto Price ($)')
plt.legend(my_crypto.columns.values, loc= 'upper left')
plt.show()

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 100))
scaled = min_max_scaler.fit_transform(df)
scaled
# Out:
# array([[1.19979445e-01, 7.64097042e-03, 8.37514246e-01],
#        [1.11246111e-01, 6.40717302e-03, 8.14827668e-01],
#        [7.65491881e-02, 6.56433591e-03, 6.86229611e-01],
#        ...,
#        [5.55203497e+01,            nan, 3.73088928e+01],
#        [5.30898670e+01,            nan, 3.55355437e+01],
#        [5.38610356e+01,            nan, 3.57723475e+01]])

# %%
df_scale = pd.DataFrame(scaled, columns = df.columns)

# %%
my_crypto = df_scale
plt.figure(figsize=(12.4, 4.5))
for c in my_crypto.columns.values:
   plt.plot(my_crypto[c], label=c)
plt.title('Cryptocurrency Scaled Graph')
plt.xlabel('Days')
plt.ylabel('Crypto Scaled Price ($)')
plt.legend(my_crypto.columns.values, loc = 'upper left')
plt.show()

# %%
DSR = df.pct_change(1)
DSR
# Out:
#            BTC       ETH       LTC
# 0          NaN       NaN       NaN
# 1    -0.038328 -0.068268 -0.019939
# 2    -0.158345  0.009333 -0.115322
# 3    -0.100692  0.507323 -0.112873
# 4    -0.070906  0.140075 -0.096996
# ...        ...       ...       ...
# 2986  0.009679  0.000000 -0.004607
# 2987  0.022760  0.000000  0.024360
# 2988  0.017861  0.000000  0.032978
# 2989 -0.043692  0.000000 -0.047152
# 2990  0.014496  0.000000  0.006608
#
# [2991 rows x 3 columns]

# %%
plt.figure(figsize=(12, 4.5))
for c in DSR.columns.values:
   plt.plot(DSR.index, DSR[c], label = c, lw = 2, alpha = .7)
plt.title('Daily Simple Returns')
plt.ylabel('Percentage (in decimal form')
plt.xlabel('Days')
plt.legend(DSR.columns.values, loc= 'upper right')
plt.show()

# %%
print('The cryptocurrency volatility:')
DSR.std()
# Out:
# The cryptocurrency volatility:
# BTC    0.042639
# ETH    0.053621
# LTC    0.068532
# dtype: float64

# %%
DSR.mean()
# Out:
# BTC    0.002741
# ETH    0.004094
# LTC    0.003262
# dtype: float64

# %%
DSR.corr()
# Out:
#           BTC       ETH       LTC
# BTC  1.000000 -0.005488  0.658199
# ETH -0.005488  1.000000 -0.020173
# LTC  0.658199 -0.020173  1.000000

# %%
import seaborn as sns
plt.subplots(figsize= (11,11))
sns.heatmap(DSR.corr(), annot= True, fmt= '.2%')

# %%
DCSR = (DSR+1).cumprod()
DCSR
# Out:
#              BTC          ETH        LTC
# 0            NaN          NaN        NaN
# 1       0.961672     0.931732   0.980061
# 2       0.809395     0.940428   0.867038
# 3       0.727895     1.417529   0.769174
# 4       0.676283     1.616089   0.694566
# ...          ...          ...        ...
# 2986  234.516744  3085.891871  31.237868
# 2987  239.854366  3085.891871  31.998833
# 2988  244.138518  3085.891871  33.054094
# 2989  233.471731  3085.891871  31.495527
# 2990  236.856199  3085.891871  31.703650
#
# [2991 rows x 3 columns]

# %% [markdown]
# Biểu đồ lợi nhuận đơn giản tích lũy hàng ngày

# %%
plt.figure(figsize=(12.2, 4.5))
for c in DCSR.columns.values:
  plt.plot(DCSR.index, DCSR[c], lw=2, label= c)
plt.title('Daily Cumulative Simple Return')
plt.xlabel('Days')
plt.ylabel('Growth of $1 investment')
plt.legend(DCSR.columns.values, loc = 'upper left', fontsize = 10)
plt.show()
