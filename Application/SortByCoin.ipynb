# %% [markdown]
# # Run Main.ipynb

# %%
# %run PreProccesser.ipynb
# Out:
# ['C:\\Users\\gahol\\OneDrive\\Desktop\\IE221-Data-Analys-Python\\Cryptocurrency Historical Prices Dataset\\coin_Aave.csv', 'C:\\Users\\gahol\\OneDrive\\Desktop\\IE221-Data-Analys-Python\\Cryptocurrency Historical Prices Dataset\\coin_BinanceCoin.csv', 'C:\\Users\\gahol\\OneDrive\\Desktop\\IE221-Data-Analys-Python\\Cryptocurrency Historical Prices Dataset\\coin_Bitcoin.csv', 'C:\\Users\\gahol\\OneDrive\\Desktop\\IE221-Data-Analys-Python\\Cryptocurrency Historical Prices Dataset\\coin_Cardano.csv', 'C:\\Users\\gahol\\OneDrive\\Desktop\\IE221-Data-Analys-Python\\Cryptocurrency Historical Prices Dataset\\coin_ChainLink.csv', 'C:\\Users\\gahol\\OneDrive\\Desktop\\IE221-Data-Analys-Python\\Cryptocurrency Historical Prices Dataset\\coin_Cosmos.csv', 'C:\\Users\\gahol\\OneDrive\\Desktop\\IE221-Data-Analys-Python\\Cryptocurrency Historical Prices Dataset\\coin_CryptocomCoin.csv', 'C:\\Users\\gahol\\OneDrive\\Desktop\\IE221-Data-Analys-Python\\Cryptocurrency Historical Prices Dataset\\coin_Dog
# ...

# %% [markdown]
# # Sort By Custommer Need
# like by Date - Type of Coin - data in 7 , 30 , 90 ,360 days

# %%
class SortByCoin():
    def __init__(self):
        self.data = CoinList_df
    def SortByCoin(self,CoinName,Date):
        df = self.data
        df = df[(df['Name'] == CoinName) | (df['Symbol'] == CoinName)]
        print(df)
        df.plot(x='Date',y=['High','Low','Open','Close'],kind="line", figsize=(30, 5) ,title = "ALL TIME")
        df.plot(x='Date',y=['Volume','Marketcap'],kind="line", figsize=(30, 5),title = "ALL TIME")
        '''
        lọc dữ liệu đầu vào phù hợp với yêu cầu sắp xếp ở đây là tên loại coin và tên viết tắt của nó
        sau đó sẽ visualization dữ liệu toàn phần của loại đó luôn        
        '''
        def SortByDay(df,Date):
            df = df[df['Date'] == Date]
            print(df.head(1))
        if not Date == '':
            SortByDay(df,Date)
        '''
        nếu như người dùng nhập vào ngày thì sẽ chạy vào hàm sortbyday và xuất ra toàn bộ giá trị của ngày đó ra
        '''
        def SortInDays(df):
            def SortIn7D(df):
                df['Date'] = pd.to_datetime(df.Date)
                lastdayfrom = df['Date'].max()
                critDate = lastdayfrom - (pd.Timedelta(days=7))
                days7 = df.loc[df.Date > critDate]
                print(days7)
                days7.plot(x='Date',y=['High','Low','Open','Close'],kind="line", figsize=(30, 5),title = "7 Days")
                days7.plot(x='Date',y=['Volume','Marketcap'],kind="line", figsize=(30, 5),title = "7 Days")
            def SortIn30D(df):
                df['Date'] = pd.to_datetime(df.Date)
                lastdayfrom = df['Date'].max()
                critDate = lastdayfrom - (pd.Timedelta(days=30))
                days30 = df.loc[df.Date > critDate]
                print(days30)
                days30.plot(x='Date',y=['High','Low','Open','Close'],kind="line", figsize=(30, 5),title = "30 Days")
                days30.plot(x='Date',y=['Volume','Marketcap'],kind="line", figsize=(30, 5),title = "30 Days")
            def SortIn90D(df):
                df['Date'] = pd.to_datetime(df.Date)
                lastdayfrom = df['Date'].max()
                critDate = lastdayfrom - (pd.Timedelta(days=90))
                days90 = df.loc[df.Date > critDate]
                print(days90)
                days90.plot(x='Date',y=['High','Low','Open','Close'],kind="line", figsize=(30, 5),title = "90 Days")
                days90.plot(x='Date',y=['Volume','Marketcap'],kind="line", figsize=(30, 5),title = "90 Days")
            def SortIn180D(df):
                df['Date'] = pd.to_datetime(df.Date)
                lastdayfrom = df['Date'].max()
                critDate = lastdayfrom - (pd.Timedelta(days=180))
                days180 = df.loc[df.Date > critDate]
                print(days180)
                days180.plot(x='Date',y=['High','Low','Open','Close'],kind="line", figsize=(30, 5),title = "180 Days")
                days180.plot(x='Date',y=['Volume','Marketcap'],kind="line", figsize=(30, 5),title = "180 Days")
            def SortIn360D(df):
                df['Date'] = pd.to_datetime(df.Date)
                lastdayfrom = df['Date'].max()
                critDate = lastdayfrom - (pd.Timedelta(days=360))
                days360 = df.loc[df.Date > critDate]
                print(days360)
                days360.plot(x='Date',y=['High','Low','Open','Close'],kind="line", figsize=(30, 5),title = "360 Days")
                days360.plot(x='Date',y=['Volume','Marketcap'],kind="line", figsize=(30, 5),title = "360 Days")
            # SortIn7D(df)
            # SortIn30D(df)
            # SortIn90D(df)
            # SortIn180D(df)
            # SortIn360D(df)
            SortIn7D = Button(window, text="Sort In 7 Days", width=25, command=SortIn7D(df)).pack()
            SortIn30D = Button(window, text="Sort In 30 Days", width=25, command=SortIn30D(df)).pack()
            SortIn90D = Button(window, text="Sort In 90 Days", width=25, command=SortIn90D(df)).pack()
            SortIn180D = Button(window, text="Sort In 180 Days", width=25, command=SortIn180D(df)).pack()
            SortIn360D = Button(window, text="Sort In 360 Days", width=25, command=SortIn360D(df)).pack()
        # if Date=='': 
        SortInDays = Button(window, text="Sort In Days", width=25, command=SortInDays(df)).pack()
        '''
        các lựa chọn visualization theo số ngày tính từ ngày gần với việc kết thúc thu thập dữ liệu nhất của loại coin đó
        '''


SortCoin = SortByCoin()


# #Sort By Coin
# CoinName = input("Input Coin Name : ")
# CoinName = str(CoinName)
# Date = input("Input Days (Not requirement)")
# year, month, day = Date.split('-')
# Date = '-'.join([year, month, day]) + ' 23:59:59'
# print(Date)
# SortCoin.SortByCoin(CoinName,Date)
# SortCoin.SortByCoin('BTC','2013-04-29 23:59:59')
# SortCoin.SortByCoin('Aave','')
'''
nhập theo kiểu không có màn hình tương tác
'''
    
window = Tk()
window.title('Sort By Need')
window.geometry("500x500")


CoinName = StringVar()
Date = StringVar()
def ByCoin():
    def Coin_Name():
        CoinName_info = CoinName.get()
        Date_info = Date.get()
        SortCoin.SortByCoin(CoinName_info,Date_info)
    e3 = ttk.Entry(window,textvariable = CoinName).pack()
    e4 = ttk.Entry(window,textvariable = Date).pack()
    CoinName_Date = Button(window, text="CoinName(can use Symbol or Name) And Date(Not requirement) Submit", width=75, command=Coin_Name).pack()


ByCoin =Button(window, text="Sort By Coin Submit", width=30, command=ByCoin).pack()
window.mainloop()
'''
nhập theo kiểu có màn hình tương tác
'''
# Out:
#       Unnamed: 0   SNo     Name Symbol                 Date          High  \
# 275            0     1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007
# 276            1     2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993
# 277            2     3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999
# 278            3     4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998
# 279            4     5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998
# ...          ...   ...      ...    ...                  ...           ...
# 3261        2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699
# 3262        2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899
# 3263        2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147
# 3264        2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430
# 3265        2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363
#
#                Low          Open         Close        Volume     Marketcap
# ...
