# %% [markdown]
# # From PreProcesser.ipynb

# %% [markdown]
# ## split data for forecast

# %%
Aave.drop(["Name"],axis=1, inplace=True)
Aave.drop(["SNo"],axis=1, inplace=True)
Aave.drop(["Symbol"],axis=1, inplace=True)
Aave["Date"]=pd.to_datetime(Aave["Date"])
Aave['Date_year'] = Aave["Date"].dt.year
Aave['Date_month'] = Aave["Date"].dt.month
Aave['Date_day'] = Aave["Date"].dt.day
Aave['Date_hour'] = Aave["Date"].dt.hour
Aave['Date_minute'] = Aave["Date"].dt.minute
Aave['Date_seconde'] = Aave["Date"].dt.second
Aave.drop(["Date"], axis=1, inplace=True)

BinanceCoin.drop(["Name"],axis=1, inplace=True)
BinanceCoin.drop(["SNo"],axis=1, inplace=True)
BinanceCoin.drop(["Symbol"],axis=1, inplace=True)
BinanceCoin["Date"]=pd.to_datetime(BinanceCoin["Date"])
BinanceCoin['Date_year'] = BinanceCoin["Date"].dt.year
BinanceCoin['Date_month'] = BinanceCoin["Date"].dt.month
BinanceCoin['Date_day'] = BinanceCoin["Date"].dt.day
BinanceCoin['Date_hour'] = BinanceCoin["Date"].dt.hour
BinanceCoin['Date_minute'] = BinanceCoin["Date"].dt.minute
BinanceCoin['Date_seconde'] = BinanceCoin["Date"].dt.second
BinanceCoin.drop(["Date"], axis=1, inplace=True)

Bitcoin.drop(["Name"],axis=1, inplace=True)
Bitcoin.drop(["SNo"],axis=1, inplace=True)
Bitcoin.drop(["Symbol"],axis=1, inplace=True)
Bitcoin["Date"]=pd.to_datetime(Bitcoin["Date"])
Bitcoin['Date_year'] = Bitcoin["Date"].dt.year
Bitcoin['Date_month'] = Bitcoin["Date"].dt.month
Bitcoin['Date_day'] = Bitcoin["Date"].dt.day
Bitcoin['Date_hour'] = Bitcoin["Date"].dt.hour
Bitcoin['Date_minute'] = Bitcoin["Date"].dt.minute
Bitcoin['Date_seconde'] = Bitcoin["Date"].dt.second
Bitcoin.drop(["Date"], axis=1, inplace=True)

Cardano.drop(["Name"],axis=1, inplace=True)
Cardano.drop(["SNo"],axis=1, inplace=True)
Cardano.drop(["Symbol"],axis=1, inplace=True)
Cardano["Date"]=pd.to_datetime(Cardano["Date"])
Cardano['Date_year'] = Cardano["Date"].dt.year
Cardano['Date_month'] = Cardano["Date"].dt.month
Cardano['Date_day'] = Cardano["Date"].dt.day
Cardano['Date_hour'] = Cardano["Date"].dt.hour
Cardano['Date_minute'] = Cardano["Date"].dt.minute
Cardano['Date_seconde'] = Cardano["Date"].dt.second
Cardano.drop(["Date"], axis=1, inplace=True)

ChainLink.drop(["Name"],axis=1, inplace=True)
ChainLink.drop(["SNo"],axis=1, inplace=True)
ChainLink.drop(["Symbol"],axis=1, inplace=True)
ChainLink["Date"]=pd.to_datetime(ChainLink["Date"])
ChainLink['Date_year'] = ChainLink["Date"].dt.year
ChainLink['Date_month'] = ChainLink["Date"].dt.month
ChainLink['Date_day'] = ChainLink["Date"].dt.day
ChainLink['Date_hour'] = ChainLink["Date"].dt.hour
ChainLink['Date_minute'] = ChainLink["Date"].dt.minute
ChainLink['Date_seconde'] = ChainLink["Date"].dt.second
ChainLink.drop(["Date"], axis=1, inplace=True)

Cosmos.drop(["Name"],axis=1, inplace=True)
Cosmos.drop(["SNo"],axis=1, inplace=True)
Cosmos.drop(["Symbol"],axis=1, inplace=True)
Cosmos["Date"]=pd.to_datetime(Cosmos["Date"])
Cosmos['Date_year'] = Cosmos["Date"].dt.year
Cosmos['Date_month'] = Cosmos["Date"].dt.month
Cosmos['Date_day'] = Cosmos["Date"].dt.day
Cosmos['Date_hour'] = Cosmos["Date"].dt.hour
Cosmos['Date_minute'] = Cosmos["Date"].dt.minute
Cosmos['Date_seconde'] = Cosmos["Date"].dt.second
Cosmos.drop(["Date"], axis=1, inplace=True)

CryptocomCoin.drop(["Name"],axis=1, inplace=True)
CryptocomCoin.drop(["SNo"],axis=1, inplace=True)
CryptocomCoin.drop(["Symbol"],axis=1, inplace=True)
CryptocomCoin["Date"]=pd.to_datetime(CryptocomCoin["Date"])
CryptocomCoin['Date_year'] = CryptocomCoin["Date"].dt.year
CryptocomCoin['Date_month'] = CryptocomCoin["Date"].dt.month
CryptocomCoin['Date_day'] = CryptocomCoin["Date"].dt.day
CryptocomCoin['Date_hour'] = CryptocomCoin["Date"].dt.hour
CryptocomCoin['Date_minute'] = CryptocomCoin["Date"].dt.minute
CryptocomCoin['Date_seconde'] = CryptocomCoin["Date"].dt.second
CryptocomCoin.drop(["Date"], axis=1, inplace=True)

Dogecoin.drop(["Name"],axis=1, inplace=True)
Dogecoin.drop(["SNo"],axis=1, inplace=True)
Dogecoin.drop(["Symbol"],axis=1, inplace=True)
Dogecoin["Date"]=pd.to_datetime(Dogecoin["Date"])
Dogecoin['Date_year'] = Dogecoin["Date"].dt.year
Dogecoin['Date_month'] = Dogecoin["Date"].dt.month
Dogecoin['Date_day'] = Dogecoin["Date"].dt.day
Dogecoin['Date_hour'] = Dogecoin["Date"].dt.hour
Dogecoin['Date_minute'] = Dogecoin["Date"].dt.minute
Dogecoin['Date_seconde'] = Dogecoin["Date"].dt.second
Dogecoin.drop(["Date"], axis=1, inplace=True)

EOS.drop(["Name"],axis=1, inplace=True)
EOS.drop(["SNo"],axis=1, inplace=True)
EOS.drop(["Symbol"],axis=1, inplace=True)
EOS["Date"]=pd.to_datetime(EOS["Date"])
EOS['Date_year'] = EOS["Date"].dt.year
EOS['Date_month'] = EOS["Date"].dt.month
EOS['Date_day'] = EOS["Date"].dt.day
EOS['Date_hour'] = EOS["Date"].dt.hour
EOS['Date_minute'] = EOS["Date"].dt.minute
EOS['Date_seconde'] = EOS["Date"].dt.second
EOS.drop(["Date"], axis=1, inplace=True)

Ethereum.drop(["Name"],axis=1, inplace=True)
Ethereum.drop(["SNo"],axis=1, inplace=True)
Ethereum.drop(["Symbol"],axis=1, inplace=True)
Ethereum["Date"]=pd.to_datetime(Ethereum["Date"])
Ethereum['Date_year'] = Ethereum["Date"].dt.year
Ethereum['Date_month'] = Ethereum["Date"].dt.month
Ethereum['Date_day'] = Ethereum["Date"].dt.day
Ethereum['Date_hour'] = Ethereum["Date"].dt.hour
Ethereum['Date_minute'] = Ethereum["Date"].dt.minute
Ethereum['Date_seconde'] = Ethereum["Date"].dt.second
Ethereum.drop(["Date"], axis=1, inplace=True)

Iota.drop(["Name"],axis=1, inplace=True)
Iota.drop(["SNo"],axis=1, inplace=True)
Iota.drop(["Symbol"],axis=1, inplace=True)
Iota["Date"]=pd.to_datetime(Iota["Date"])
Iota['Date_year'] = Iota["Date"].dt.year
Iota['Date_month'] = Iota["Date"].dt.month
Iota['Date_day'] = Iota["Date"].dt.day
Iota['Date_hour'] = Iota["Date"].dt.hour
Iota['Date_minute'] = Iota["Date"].dt.minute
Iota['Date_seconde'] = Iota["Date"].dt.second
Iota.drop(["Date"], axis=1, inplace=True)

Litecoin.drop(["Name"],axis=1, inplace=True)
Litecoin.drop(["SNo"],axis=1, inplace=True)
Litecoin.drop(["Symbol"],axis=1, inplace=True)
Litecoin["Date"]=pd.to_datetime(Litecoin["Date"])
Litecoin['Date_year'] = Litecoin["Date"].dt.year
Litecoin['Date_month'] = Litecoin["Date"].dt.month
Litecoin['Date_day'] = Litecoin["Date"].dt.day
Litecoin['Date_hour'] = Litecoin["Date"].dt.hour
Litecoin['Date_minute'] = Litecoin["Date"].dt.minute
Litecoin['Date_seconde'] = Litecoin["Date"].dt.second
Litecoin.drop(["Date"], axis=1, inplace=True)

Monero.drop(["Name"],axis=1, inplace=True)
Monero.drop(["SNo"],axis=1, inplace=True)
Monero.drop(["Symbol"],axis=1, inplace=True)
Monero["Date"]=pd.to_datetime(Monero["Date"])
Monero['Date_year'] = Monero["Date"].dt.year
Monero['Date_month'] = Monero["Date"].dt.month
Monero['Date_day'] = Monero["Date"].dt.day
Monero['Date_hour'] = Monero["Date"].dt.hour
Monero['Date_minute'] = Monero["Date"].dt.minute
Monero['Date_seconde'] = Monero["Date"].dt.second
Monero.drop(["Date"], axis=1, inplace=True)

NEM.drop(["Name"],axis=1, inplace=True)
NEM.drop(["SNo"],axis=1, inplace=True)
NEM.drop(["Symbol"],axis=1, inplace=True)
NEM["Date"]=pd.to_datetime(NEM["Date"])
NEM['Date_year'] = NEM["Date"].dt.year
NEM['Date_month'] = NEM["Date"].dt.month
NEM['Date_day'] = NEM["Date"].dt.day
NEM['Date_hour'] = NEM["Date"].dt.hour
NEM['Date_minute'] = NEM["Date"].dt.minute
NEM['Date_seconde'] = NEM["Date"].dt.second
NEM.drop(["Date"], axis=1, inplace=True)

Polkadot.drop(["Name"],axis=1, inplace=True)
Polkadot.drop(["SNo"],axis=1, inplace=True)
Polkadot.drop(["Symbol"],axis=1, inplace=True)
Polkadot["Date"]=pd.to_datetime(Polkadot["Date"])
Polkadot['Date_year'] = Polkadot["Date"].dt.year
Polkadot['Date_month'] = Polkadot["Date"].dt.month
Polkadot['Date_day'] = Polkadot["Date"].dt.day
Polkadot['Date_hour'] = Polkadot["Date"].dt.hour
Polkadot['Date_minute'] = Polkadot["Date"].dt.minute
Polkadot['Date_seconde'] = Polkadot["Date"].dt.second
Polkadot.drop(["Date"], axis=1, inplace=True)

Solana.drop(["Name"],axis=1, inplace=True)
Solana.drop(["SNo"],axis=1, inplace=True)
Solana.drop(["Symbol"],axis=1, inplace=True)
Solana["Date"]=pd.to_datetime(Solana["Date"])
Solana['Date_year'] = Solana["Date"].dt.year
Solana['Date_month'] = Solana["Date"].dt.month
Solana['Date_day'] = Solana["Date"].dt.day
Solana['Date_hour'] = Solana["Date"].dt.hour
Solana['Date_minute'] = Solana["Date"].dt.minute
Solana['Date_seconde'] = Solana["Date"].dt.second
Solana.drop(["Date"], axis=1, inplace=True)

Stellar.drop(["Name"],axis=1, inplace=True)
Stellar.drop(["SNo"],axis=1, inplace=True)
Stellar.drop(["Symbol"],axis=1, inplace=True)
Stellar["Date"]=pd.to_datetime(Stellar["Date"])
Stellar['Date_year'] = Stellar["Date"].dt.year
Stellar['Date_month'] = Stellar["Date"].dt.month
Stellar['Date_day'] = Stellar["Date"].dt.day
Stellar['Date_hour'] = Stellar["Date"].dt.hour
Stellar['Date_minute'] = Stellar["Date"].dt.minute
Stellar['Date_seconde'] = Stellar["Date"].dt.second
Stellar.drop(["Date"], axis=1, inplace=True)

Tether.drop(["Name"],axis=1, inplace=True)
Tether.drop(["SNo"],axis=1, inplace=True)
Tether.drop(["Symbol"],axis=1, inplace=True)
Tether["Date"]=pd.to_datetime(Tether["Date"])
Tether['Date_year'] = Tether["Date"].dt.year
Tether['Date_month'] = Tether["Date"].dt.month
Tether['Date_day'] = Tether["Date"].dt.day
Tether['Date_hour'] = Tether["Date"].dt.hour
Tether['Date_minute'] = Tether["Date"].dt.minute
Tether['Date_seconde'] = Tether["Date"].dt.second
Tether.drop(["Date"], axis=1, inplace=True)

Tron.drop(["Name"],axis=1, inplace=True)
Tron.drop(["SNo"],axis=1, inplace=True)
Tron.drop(["Symbol"],axis=1, inplace=True)
Tron["Date"]=pd.to_datetime(Tron["Date"])
Tron['Date_year'] = Tron["Date"].dt.year
Tron['Date_month'] = Tron["Date"].dt.month
Tron['Date_day'] = Tron["Date"].dt.day
Tron['Date_hour'] = Tron["Date"].dt.hour
Tron['Date_minute'] = Tron["Date"].dt.minute
Tron['Date_seconde'] = Tron["Date"].dt.second
Tron.drop(["Date"], axis=1, inplace=True)

Uniswap.drop(["Name"],axis=1, inplace=True)
Uniswap.drop(["SNo"],axis=1, inplace=True)
Uniswap.drop(["Symbol"],axis=1, inplace=True)
Uniswap["Date"]=pd.to_datetime(Uniswap["Date"])
Uniswap['Date_year'] =Uniswap["Date"].dt.year
Uniswap['Date_month'] = Uniswap["Date"].dt.month
Uniswap['Date_day'] = Uniswap["Date"].dt.day
Uniswap['Date_hour'] = Uniswap["Date"].dt.hour
Uniswap['Date_minute'] = Uniswap["Date"].dt.minute
Uniswap['Date_seconde'] = Uniswap["Date"].dt.second
Uniswap.drop(["Date"], axis=1, inplace=True)

USDCoin.drop(["Name"],axis=1, inplace=True)
USDCoin.drop(["SNo"],axis=1, inplace=True)
USDCoin.drop(["Symbol"],axis=1, inplace=True)
USDCoin["Date"]=pd.to_datetime(USDCoin["Date"])
USDCoin['Date_year'] = USDCoin["Date"].dt.year
USDCoin['Date_month'] = USDCoin["Date"].dt.month
USDCoin['Date_day'] = USDCoin["Date"].dt.day
USDCoin['Date_hour'] = USDCoin["Date"].dt.hour
USDCoin['Date_minute'] = USDCoin["Date"].dt.minute
USDCoin['Date_seconde'] = USDCoin["Date"].dt.second
USDCoin.drop(["Date"], axis=1, inplace=True)

WrappedBitcoin.drop(["Name"],axis=1, inplace=True)
WrappedBitcoin.drop(["SNo"],axis=1, inplace=True)
WrappedBitcoin.drop(["Symbol"],axis=1, inplace=True)
WrappedBitcoin["Date"]=pd.to_datetime(WrappedBitcoin["Date"])
WrappedBitcoin['Date_year'] = WrappedBitcoin["Date"].dt.year
WrappedBitcoin['Date_month'] = WrappedBitcoin["Date"].dt.month
WrappedBitcoin['Date_day'] = WrappedBitcoin["Date"].dt.day
WrappedBitcoin['Date_hour'] = WrappedBitcoin["Date"].dt.hour
WrappedBitcoin['Date_minute'] = WrappedBitcoin["Date"].dt.minute
WrappedBitcoin['Date_seconde'] = WrappedBitcoin["Date"].dt.second
WrappedBitcoin.drop(["Date"], axis=1, inplace=True)

XRP.drop(["Name"],axis=1, inplace=True)
XRP.drop(["SNo"],axis=1, inplace=True)
XRP.drop(["Symbol"],axis=1, inplace=True)
XRP["Date"]=pd.to_datetime(XRP["Date"])
XRP['Date_year'] = XRP["Date"].dt.year
XRP['Date_month'] = XRP["Date"].dt.month
XRP['Date_day'] = XRP["Date"].dt.day
XRP['Date_hour'] = XRP["Date"].dt.hour
XRP['Date_minute'] = XRP["Date"].dt.minute
XRP['Date_seconde'] = XRP["Date"].dt.second
XRP.drop(["Date"], axis=1, inplace=True)

# %%
XAave = Aave.drop(["Marketcap"], axis=1)
YAave = Aave['Marketcap']
XBinanceCoin = BinanceCoin.drop(["Marketcap"], axis=1)
YBinanceCoin = BinanceCoin['Marketcap']
XBitcoin = Bitcoin.drop(["Marketcap"], axis=1)
YBitcoin = Bitcoin['Marketcap']
XCardano = Cardano.drop(["Marketcap"], axis=1)
YCardano = Cardano['Marketcap']
XChainLink = ChainLink.drop(["Marketcap"], axis=1)
YChainLink = ChainLink['Marketcap']
XCosmos = Cosmos.drop(["Marketcap"], axis=1)
YCosmos = Cosmos['Marketcap']
XCryptocomCoin = CryptocomCoin.drop(["Marketcap"], axis=1)
YCryptocomCoin = CryptocomCoin['Marketcap']
XDogecoin = Dogecoin.drop(["Marketcap"], axis=1)
YDogecoin = Dogecoin['Marketcap']
XEOS = EOS.drop(["Marketcap"], axis=1)
YEOS = EOS['Marketcap']
XEthereum = Ethereum.drop(["Marketcap"], axis=1)
YEthereum = Ethereum['Marketcap']
XIota = Iota.drop(["Marketcap"], axis=1)
YIota = Iota['Marketcap']
XLitecoin = Litecoin.drop(["Marketcap"], axis=1)
YLitecoin = Litecoin['Marketcap']
XMonero = Monero.drop(["Marketcap"], axis=1)
YMonero = Monero['Marketcap']
XNEM = NEM.drop(["Marketcap"], axis=1)
YNEM = NEM['Marketcap']
XPolkadot = Polkadot.drop(["Marketcap"], axis=1)
YPolkadot = Polkadot['Marketcap']
XSolana = Solana.drop(["Marketcap"], axis=1)
YSolana = Solana['Marketcap']
XStellar = Stellar.drop(["Marketcap"], axis=1)
YStellar = Stellar['Marketcap']
XTether = Tether.drop(["Marketcap"], axis=1)
YTether = Tether['Marketcap']
XTron = Tron.drop(["Marketcap"], axis=1)
YTron = Tron['Marketcap']
XUniswap = Uniswap.drop(["Marketcap"], axis=1)
YUniswap = Uniswap['Marketcap']
XUSDCoin = USDCoin.drop(["Marketcap"], axis=1)
YUSDCoin = USDCoin['Marketcap']
XWrappedBitcoin = WrappedBitcoin.drop(["Marketcap"], axis=1)
YWrappedBitcoin= WrappedBitcoin['Marketcap']
XXRP = XRP.drop(["Marketcap"], axis=1)
YXRP = XRP['Marketcap']

# %%
XAave_train, XAave_test,YAave_train, YAave_test = train_test_split(XAave,YAave, test_size=0.33, random_state=42)
XBinanceCoin_train, XBinanceCoin_test,YBinanceCoin_train, YBinanceCoin_test = train_test_split(XBinanceCoin,YBinanceCoin, test_size=0.33, random_state=42)
XBitcoin_train, XBitcoin_test,YBitcoin_train, YBitcoin_test = train_test_split(XBitcoin,YBitcoin, test_size=0.33, random_state=42)
XCardano_train, XCardano_test,YCardano_train, YCardano_test = train_test_split(XCardano,YCardano, test_size=0.33, random_state=42)
XChainLink_train, XChainLink_test,YChainLink_train, YChainLink_test = train_test_split(XChainLink,YChainLink, test_size=0.33, random_state=42)
XCosmos_train, XCosmos_test,YCosmos_train, YCosmos_test = train_test_split(XCosmos,YCosmos, test_size=0.33, random_state=42)
XCryptocomCoin_train, XCryptocomCoin_test,YCryptocomCoin_train, YCryptocomCoin_test = train_test_split(XCryptocomCoin,YCryptocomCoin, test_size=0.33, random_state=42)
XDogecoin_train, XDogecoin_test,YDogecoin_train, YDogecoin_test = train_test_split(XDogecoin,YDogecoin, test_size=0.33, random_state=42)
XEOS_train, XEOS_test,YEOS_train, YEOS_test = train_test_split(XEOS,YEOS, test_size=0.33, random_state=42)
XEthereum_train, XEthereum_test,YEthereum_train, YEthereum_test = train_test_split(XEthereum,YEthereum, test_size=0.33, random_state=42)
XIota_train, XIota_test,YIota_train, YIota_test = train_test_split(XIota,YIota, test_size=0.33, random_state=42)
XLitecoin_train, XLitecoin_test,YLitecoin_train, YLitecoin_test = train_test_split(XLitecoin,YLitecoin, test_size=0.33, random_state=42)
XMonero_train, XMonero_test,YMonero_train, YMonero_test = train_test_split(XMonero,YMonero, test_size=0.33, random_state=42)
XNEM_train, XNEM_test,YNEM_train, YNEM_test = train_test_split(XNEM,YNEM, test_size=0.33, random_state=42)
XPolkadot_train, XPolkadot_test,YPolkadot_train, YPolkadot_test = train_test_split(XPolkadot,YPolkadot, test_size=0.33, random_state=42)
XSolana_train, XSolana_test,YSolana_train, YSolana_test = train_test_split(XSolana,YSolana, test_size=0.33, random_state=42)
XStellar_train, XStellar_test,YStellar_train, YStellar_test = train_test_split(XStellar,YStellar, test_size=0.33, random_state=42)
XTether_train, XTether_test,YTether_train, YTether_test = train_test_split(XTether,YTether, test_size=0.33, random_state=42)
XTron_train, XTron_test,YTron_train, YTron_test = train_test_split(XTron,YTron, test_size=0.33, random_state=42)
XUniswap_train, XUniswap_test,YUniswap_train, YUniswap_test = train_test_split(XUniswap,YUniswap, test_size=0.33, random_state=42)
XUSDCoin_train, XUSDCoin_test,YUSDCoin_train, YUSDCoin_test = train_test_split(XUSDCoin,YUSDCoin, test_size=0.33, random_state=42)
XWrappedBitcoin_train, XWrappedBitcoin_test,YWrappedBitcoin_train, YWrappedBitcoin_test = train_test_split(XWrappedBitcoin,YWrappedBitcoin, test_size=0.33, random_state=42)
XXRP_train, XXRP_test,YXRP_train, YXRP_test = train_test_split(XXRP,YXRP, test_size=0.33, random_state=42)

# %% [markdown]
# # From SortByNeed.ipynb

# %% [markdown]
# # From Forecast.ipynb

# %%
    def Linear_Regression(self):
        plt.figure(figsize=(20,5))
        def AavePre():
            model=LinearRegression()
            model.fit(XAave_train,YAave_train)
            ypred=model.predict(XAave_test)
            print(pd.DataFrame({'real_value':YAave_test,'pred_value':ypred}))
            print(model.score(XAave_test,YAave_test))
            plt.plot(ypred)
            plt.legend(['Aave ypred'])
        def BinanceCoinPre():
            model=LinearRegression()
            model.fit(XBinanceCoin_train,YBinanceCoin_train)
            ypred=model.predict(XBinanceCoin_test)
            print(pd.DataFrame({'real_value':YBinanceCoin_test,'pred_value':ypred}))
            print(model.score(XBinanceCoin_test,YBinanceCoin_test))
            plt.plot(ypred)
            plt.legend(['BinanceCoin ypred'])
        def BitcoinPre():
            model=LinearRegression()
            model.fit(XBitcoin_train,YBitcoin_train)
            ypred=model.predict(XBitcoin_test)
            print(pd.DataFrame({'real_value':YBitcoin_test,'pred_value':ypred}))
            print(model.score(XBitcoin_test,YBitcoin_test))
            plt.plot(ypred)
            plt.legend(['Bitcoin ypred'])
        def CardanoPre():
            model=LinearRegression()
            model.fit(XCardano_train,YCardano_train)
            ypred=model.predict(XCardano_test)
            print(pd.DataFrame({'real_value':YCardano_test,'pred_value':ypred}))
            print(model.score(XCardano_test,YCardano_test))
            plt.plot(ypred)
            plt.legend(['Cardano ypred'])
        def ChainLinkPre():
            model=LinearRegression()
            model.fit(XChainLink_train,YChainLink_train)
            ypred=model.predict(XChainLink_test)
            print(pd.DataFrame({'real_value':YChainLink_test,'pred_value':ypred}))
            print(model.score(XChainLink_test,YChainLink_test))
            plt.plot(ypred)
            plt.legend(['ChainLink ypred'])
        def CosmosPre():
            model=LinearRegression()
            model.fit(XCosmos_train,YCosmos_train)
            ypred=model.predict(XCosmos_test)
            print(pd.DataFrame({'real_value':YCosmos_test,'pred_value':ypred}))
            print(model.score(XCosmos_test,YCosmos_test))
            plt.plot(ypred)
            plt.legend(['Cosmos ypred'])
        def CryptocomCoinPre():
            model=LinearRegression()
            model.fit(XCryptocomCoin_train,YCryptocomCoin_train)
            ypred=model.predict(XCryptocomCoin_test)
            print(pd.DataFrame({'real_value':YCryptocomCoin_test,'pred_value':ypred}))
            print(model.score(XCryptocomCoin_test,YCryptocomCoin_test))
            plt.plot(ypred)
            plt.legend(['CrytocomCoin ypred'])
        def DogecoinPre():
            model=LinearRegression()
            model.fit(XDogecoin_train,YDogecoin_train)
            ypred=model.predict(XDogecoin_test)
            print(pd.DataFrame({'real_value':YDogecoin_test,'pred_value':ypred}))
            print(model.score(XDogecoin_test,YDogecoin_test))
            plt.plot(ypred)
            plt.legend(['Dogecoin ypred'])
        def EOSPre():
            model=LinearRegression()
            model.fit(XEOS_train,YEOS_train)
            ypred=model.predict(XEOS_test)
            print(pd.DataFrame({'real_value':YEOS_test,'pred_value':ypred}))
            print(model.score(XEOS_test,YEOS_test))
            plt.plot(ypred)
            plt.legend(['EOS ypred'])
        def EthereumPre():
            model=LinearRegression()
            model.fit(XEthereum_train,YEthereum_train)
            ypred=model.predict(XEthereum_test)
            print(pd.DataFrame({'real_value':YEthereum_test,'pred_value':ypred}))
            print(model.score(XEthereum_test,YEthereum_test))
            plt.plot(ypred)
            plt.legend(['Ethereum ypred'])
        def IotaPre():
            model=LinearRegression()
            model.fit(XIota_train,YIota_train)
            ypred=model.predict(XIota_test)
            print(pd.DataFrame({'real_value':YIota_test,'pred_value':ypred}))
            print(model.score(XIota_test,YIota_test))
            plt.plot(ypred)
            plt.legend(['Iota ypred'])
        def LitecoinPre():
            model=LinearRegression()
            model.fit(XLitecoin_train,YLitecoin_train)
            ypred=model.predict(XLitecoin_test)
            print(pd.DataFrame({'real_value':YLitecoin_test,'pred_value':ypred}))
            print(model.score(XLitecoin_test,YLitecoin_test))
            plt.plot(ypred)
            plt.legend(['Litecoin ypred'])
        def MoneroPre():
            model=LinearRegression()
            model.fit(XMonero_train,YMonero_train)
            ypred=model.predict(XMonero_test)
            print(pd.DataFrame({'real_value':YMonero_test,'pred_value':ypred}))
            print(model.score(XMonero_test,YMonero_test))
            plt.plot(ypred)
            plt.legend(['Monero ypred'])
        def NEMPre():
            model=LinearRegression()
            model.fit(XNEM_train,YNEM_train)
            ypred=model.predict(XNEM_test)
            print(pd.DataFrame({'real_value':YNEM_test,'pred_value':ypred}))
            print(model.score(XNEM_test,YNEM_test))
            plt.plot(ypred)
            plt.legend(['NEM ypred'])
        def PolkadotPre():
            model=LinearRegression()
            model.fit(XPolkadot_train,YPolkadot_train)
            ypred=model.predict(XPolkadot_test)
            print(pd.DataFrame({'real_value':YPolkadot_test,'pred_value':ypred}))
            print(model.score(XPolkadot_test,YPolkadot_test))
            plt.plot(ypred)
            plt.legend(['Polkadot ypred'])
        def SolanaPre():
            model=LinearRegression()
            model.fit(XSolana_train,YSolana_train)
            ypred=model.predict(XSolana_test)
            print(pd.DataFrame({'real_value':YSolana_test,'pred_value':ypred}))
            print(model.score(XSolana_test,YSolana_test))
            plt.plot(ypred)
            plt.legend(['Solana ypred'])
        def StellarPre():
            model=LinearRegression()
            model.fit(XStellar_train,YStellar_train)
            ypred=model.predict(XStellar_test)
            print(pd.DataFrame({'real_value':YStellar_test,'pred_value':ypred}))
            print(model.score(XStellar_test,YStellar_test))
            plt.plot(ypred)
            plt.legend(['Stellar ypred'])
        def TetherPre():
            model=LinearRegression()
            model.fit(XTether_train,YTether_train)
            ypred=model.predict(XTether_test)
            print(pd.DataFrame({'real_value':YTether_test,'pred_value':ypred}))
            print(model.score(XTether_test,YTether_test))
            plt.plot(ypred)
            plt.legend(['Tether ypred'])
        def TronPre():
            model=LinearRegression()
            model.fit(XTron_train,YTron_train)
            ypred=model.predict(XTron_test)
            print(pd.DataFrame({'real_value':YTron_test,'pred_value':ypred}))
            print(model.score(XTron_test,YTron_test))
            plt.plot(ypred)
            plt.legend(['Tron ypred'])
        def UniswapPre():
            model=LinearRegression()
            model.fit(XUniswap_train,YUniswap_train)
            ypred=model.predict(XUniswap_test)
            print(pd.DataFrame({'real_value':YUniswap_test,'pred_value':ypred}))
            print(model.score(XUniswap_test,YUniswap_test))
            plt.plot(ypred)
            plt.legend(['Uniswap ypred'])
        def USDCoinPre():
            model=LinearRegression()
            model.fit(XUSDCoin_train,YUSDCoin_train)
            ypred=model.predict(XUSDCoin_test)
            print(pd.DataFrame({'real_value':YUSDCoin_test,'pred_value':ypred}))
            print(model.score(XUSDCoin_test,YUSDCoin_test))
            plt.plot(ypred)
            plt.legend(['USDCoin ypred'])
        def WrappedBitcoinPre():
            model=LinearRegression()
            model.fit(XWrappedBitcoin_train,YWrappedBitcoin_train)
            ypred=model.predict(XWrappedBitcoin_test)
            print(pd.DataFrame({'real_value':YWrappedBitcoin_test,'pred_value':ypred}))
            print(model.score(XWrappedBitcoin_test,YWrappedBitcoin_test))
            plt.plot(ypred)
            plt.legend(['WrappedBitcoin ypred'])
        def XRPPre():
            model=LinearRegression()
            model.fit(XXRP_train,YXRP_train)
            ypred=model.predict(XXRP_test)
            print(pd.DataFrame({'real_value':YXRP_test,'pred_value':ypred}))
            print(model.score(XXRP_test,YXRP_test))
            plt.plot(ypred)
            plt.legend(['XRP ypred'])
        def runAll():
            if __name__ == '__main__':
                plt.title(' Model Linear Regession Predict By MarketCap')
                Thread(AavePre()).start()
                # Thread(BinanceCoinPre()).start()
                # Thread(BitcoinPre()).start()
                # Thread(CardanoPre()).start()
                # Thread(ChainLinkPre()).start()
                # Thread(CosmosPre()).start()
                # Thread(CryptocomCoinPre()).start()
                # Thread(DogecoinPre()).start()
                # Thread(EOSPre()).start()                
                # Thread(EthereumPre()).start()
                # Thread(IotaPre()).start()
                # Thread(LitecoinPre()).start()
                # Thread(MoneroPre()).start()
                # Thread(NEMPre()).start()
                # Thread(PolkadotPre()).start()
                # Thread(SolanaPre()).start()
                # Thread(StellarPre()).start()
                # Thread(TetherPre()).start()
                # Thread(TronPre()).start()
                # Thread(UniswapPre()).start()
                # Thread(USDCoinPre()).start()
                # Thread(WrappedBitcoinPre()).start()
                # Thread(XRPPre()).start()
        runAll()
        
    def Lasso(self):
        plt.figure(figsize=(20,5))
        def AavePre():
            model=Lasso()
            model.fit(XAave_train,YAave_train)
            ypred=model.predict(XAave_test)
            print(pd.DataFrame({'real_value':YAave_test,'pred_value':ypred}))
            print(model.score(XAave_test,YAave_test))
            plt.plot(ypred)
            plt.legend(['Aave ypred'])
        def BinanceCoinPre():
            model=Lasso()
            model.fit(XBinanceCoin_train,YBinanceCoin_train)
            ypred=model.predict(XBinanceCoin_test)
            print(pd.DataFrame({'real_value':YBinanceCoin_test,'pred_value':ypred}))
            print(model.score(XBinanceCoin_test,YBinanceCoin_test))
            plt.plot(ypred)
            plt.legend(['BinanceCoin ypred'])
        def BitcoinPre():
            model=Lasso()
            model.fit(XBitcoin_train,YBitcoin_train)
            ypred=model.predict(XBitcoin_test)
            print(pd.DataFrame({'real_value':YBitcoin_test,'pred_value':ypred}))
            print(model.score(XBitcoin_test,YBitcoin_test))
            plt.plot(ypred)
            plt.legend(['Bitcoin ypred'])
        def CardanoPre():
            model=Lasso()
            model.fit(XCardano_train,YCardano_train)
            ypred=model.predict(XCardano_test)
            print(pd.DataFrame({'real_value':YCardano_test,'pred_value':ypred}))
            print(model.score(XCardano_test,YCardano_test))
            plt.plot(ypred)
            plt.legend(['Cardano ypred'])
        def ChainLinkPre():
            model=Lasso()
            model.fit(XChainLink_train,YChainLink_train)
            ypred=model.predict(XChainLink_test)
            print(pd.DataFrame({'real_value':YChainLink_test,'pred_value':ypred}))
            print(model.score(XChainLink_test,YChainLink_test))
            plt.plot(ypred)
            plt.legend(['ChainLink ypred'])
        def CosmosPre():
            model=Lasso()
            model.fit(XCosmos_train,YCosmos_train)
            ypred=model.predict(XCosmos_test)
            print(pd.DataFrame({'real_value':YCosmos_test,'pred_value':ypred}))
            print(model.score(XCosmos_test,YCosmos_test))
            plt.plot(ypred)
            plt.legend(['Cosmos ypred'])
        def CryptocomCoinPre():
            model=Lasso()
            model.fit(XCryptocomCoin_train,YCryptocomCoin_train)
            ypred=model.predict(XCryptocomCoin_test)
            print(pd.DataFrame({'real_value':YCryptocomCoin_test,'pred_value':ypred}))
            print(model.score(XCryptocomCoin_test,YCryptocomCoin_test))
            plt.plot(ypred)
            plt.legend(['CrytocomCoin ypred'])
        def DogecoinPre():
            model=Lasso()
            model.fit(XDogecoin_train,YDogecoin_train)
            ypred=model.predict(XDogecoin_test)
            print(pd.DataFrame({'real_value':YDogecoin_test,'pred_value':ypred}))
            print(model.score(XDogecoin_test,YDogecoin_test))
            plt.plot(ypred)
            plt.legend(['Dogecoin ypred'])
        def EOSPre():
            model=Lasso()
            model.fit(XEOS_train,YEOS_train)
            ypred=model.predict(XEOS_test)
            print(pd.DataFrame({'real_value':YEOS_test,'pred_value':ypred}))
            print(model.score(XEOS_test,YEOS_test))
            plt.plot(ypred)
            plt.legend(['EOS ypred'])
        def EthereumPre():
            model=Lasso()
            model.fit(XEthereum_train,YEthereum_train)
            ypred=model.predict(XEthereum_test)
            print(pd.DataFrame({'real_value':YEthereum_test,'pred_value':ypred}))
            print(model.score(XEthereum_test,YEthereum_test))
            plt.plot(ypred)
            plt.legend(['Ethereum ypred'])
        def IotaPre():
            model=Lasso()
            model.fit(XIota_train,YIota_train)
            ypred=model.predict(XIota_test)
            print(pd.DataFrame({'real_value':YIota_test,'pred_value':ypred}))
            print(model.score(XIota_test,YIota_test))
            plt.plot(ypred)
            plt.legend(['Iota ypred'])
        def LitecoinPre():
            model=Lasso()
            model.fit(XLitecoin_train,YLitecoin_train)
            ypred=model.predict(XLitecoin_test)
            print(pd.DataFrame({'real_value':YLitecoin_test,'pred_value':ypred}))
            print(model.score(XLitecoin_test,YLitecoin_test))
            plt.plot(ypred)
            plt.legend(['Litecoin ypred'])
        def MoneroPre():
            model=Lasso()
            model.fit(XMonero_train,YMonero_train)
            ypred=model.predict(XMonero_test)
            print(pd.DataFrame({'real_value':YMonero_test,'pred_value':ypred}))
            print(model.score(XMonero_test,YMonero_test))
            plt.plot(ypred)
            plt.legend(['Monero ypred'])
        def NEMPre():
            model=Lasso()
            model.fit(XNEM_train,YNEM_train)
            ypred=model.predict(XNEM_test)
            print(pd.DataFrame({'real_value':YNEM_test,'pred_value':ypred}))
            print(model.score(XNEM_test,YNEM_test))
            plt.plot(ypred)
            plt.legend(['NEM ypred'])
        def PolkadotPre():
            model=Lasso()
            model.fit(XPolkadot_train,YPolkadot_train)
            ypred=model.predict(XPolkadot_test)
            print(pd.DataFrame({'real_value':YPolkadot_test,'pred_value':ypred}))
            print(model.score(XPolkadot_test,YPolkadot_test))
            plt.plot(ypred)
            plt.legend(['Polkadot ypred'])
        def SolanaPre():
            model=Lasso()
            model.fit(XSolana_train,YSolana_train)
            ypred=model.predict(XSolana_test)
            print(pd.DataFrame({'real_value':YSolana_test,'pred_value':ypred}))
            print(model.score(XSolana_test,YSolana_test))
            plt.plot(ypred)
            plt.legend(['Solana ypred'])
        def StellarPre():
            model=Lasso()
            model.fit(XStellar_train,YStellar_train)
            ypred=model.predict(XStellar_test)
            print(pd.DataFrame({'real_value':YStellar_test,'pred_value':ypred}))
            print(model.score(XStellar_test,YStellar_test))
            plt.plot(ypred)
            plt.legend(['Stellar ypred'])
        def TetherPre():
            model=Lasso()
            model.fit(XTether_train,YTether_train)
            ypred=model.predict(XTether_test)
            print(pd.DataFrame({'real_value':YTether_test,'pred_value':ypred}))
            print(model.score(XTether_test,YTether_test))
            plt.plot(ypred)
            plt.legend(['Tether ypred'])
        def TronPre():
            model=Lasso()
            model.fit(XTron_train,YTron_train)
            ypred=model.predict(XTron_test)
            print(pd.DataFrame({'real_value':YTron_test,'pred_value':ypred}))
            print(model.score(XTron_test,YTron_test))
            plt.plot(ypred)
            plt.legend(['Tron ypred'])
        def UniswapPre():
            model=Lasso()
            model.fit(XUniswap_train,YUniswap_train)
            ypred=model.predict(XUniswap_test)
            print(pd.DataFrame({'real_value':YUniswap_test,'pred_value':ypred}))
            print(model.score(XUniswap_test,YUniswap_test))
            plt.plot(ypred)
            plt.legend(['Uniswap ypred'])
        def USDCoinPre():
            model=Lasso()
            model.fit(XUSDCoin_train,YUSDCoin_train)
            ypred=model.predict(XUSDCoin_test)
            print(pd.DataFrame({'real_value':YUSDCoin_test,'pred_value':ypred}))
            print(model.score(XUSDCoin_test,YUSDCoin_test))
            plt.plot(ypred)
            plt.legend(['USDCoin ypred'])
        def WrappedBitcoinPre():
            model=Lasso()
            model.fit(XWrappedBitcoin_train,YWrappedBitcoin_train)
            ypred=model.predict(XWrappedBitcoin_test)
            print(pd.DataFrame({'real_value':YWrappedBitcoin_test,'pred_value':ypred}))
            print(model.score(XWrappedBitcoin_test,YWrappedBitcoin_test))
            plt.plot(ypred)
            plt.legend(['WrappedBitcoin ypred'])
        def XRPPre():
            model=Lasso()
            model.fit(XXRP_train,YXRP_train)
            ypred=model.predict(XXRP_test)
            print(pd.DataFrame({'real_value':YXRP_test,'pred_value':ypred}))
            print(model.score(XXRP_test,YXRP_test))
            plt.plot(ypred)
            plt.legend(['XRP ypred'])
        def runAll():
            if __name__ == '__main__':
                plt.title('Model Lasso Predict By MarketCap')
                Thread(AavePre()).start()
                # Thread(BinanceCoinPre()).start()
                # Thread(BitcoinPre()).start()
                # Thread(CardanoPre()).start()
                # Thread(ChainLinkPre()).start()
                # Thread(CosmosPre()).start()
                # Thread(CryptocomCoinPre()).start()
                # Thread(DogecoinPre()).start()
                # Thread(EOSPre()).start()                
                # Thread(EthereumPre()).start()
                # Thread(IotaPre()).start()
                # Thread(LitecoinPre()).start()
                # Thread(MoneroPre()).start()
                # Thread(NEMPre()).start()
                # Thread(PolkadotPre()).start()
                # Thread(SolanaPre()).start()
                # Thread(StellarPre()).start()
                # Thread(TetherPre()).start()
                # Thread(TronPre()).start()
                # Thread(UniswapPre()).start()
                # Thread(USDCoinPre()).start()
                # Thread(WrappedBitcoinPre()).start()
                # Thread(XRPPre()).start()
        runAll()
    def Decision_Tree_Regressor(self):
        plt.figure(figsize=(20,5))
        def AavePre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XAave_train,YAave_train)
            ypred=model.predict(XAave_test)
            print(pd.DataFrame({'real_value':YAave_test,'pred_value':ypred}))
            print(model.score(XAave_test,YAave_test))
            plt.plot(ypred)
            plt.legend(['Aave ypred'])
        AavePre()
        def BinanceCoinPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XBinanceCoin_train,YBinanceCoin_train)
            ypred=model.predict(XBinanceCoin_test)
            print(pd.DataFrame({'real_value':YBinanceCoin_test,'pred_value':ypred}))
            print(model.score(XBinanceCoin_test,YBinanceCoin_test))
            plt.plot(ypred)
            plt.legend(['BinanceCoin ypred'])
        def BitcoinPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XBitcoin_train,YBitcoin_train)
            ypred=model.predict(XBitcoin_test)
            print(pd.DataFrame({'real_value':YBitcoin_test,'pred_value':ypred}))
            print(model.score(XBitcoin_test,YBitcoin_test))
            plt.plot(ypred)
            plt.legend(['Bitcoin ypred'])
        def CardanoPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XCardano_train,YCardano_train)
            ypred=model.predict(XCardano_test)
            print(pd.DataFrame({'real_value':YCardano_test,'pred_value':ypred}))
            print(model.score(XCardano_test,YCardano_test))
            plt.plot(ypred)
            plt.legend(['Cardano ypred'])
        def ChainLinkPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XChainLink_train,YChainLink_train)
            ypred=model.predict(XChainLink_test)
            print(pd.DataFrame({'real_value':YChainLink_test,'pred_value':ypred}))
            print(model.score(XChainLink_test,YChainLink_test))
            plt.plot(ypred)
            plt.legend(['ChainLink ypred'])
        def CosmosPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XCosmos_train,YCosmos_train)
            ypred=model.predict(XCosmos_test)
            print(pd.DataFrame({'real_value':YCosmos_test,'pred_value':ypred}))
            print(model.score(XCosmos_test,YCosmos_test))
            plt.plot(ypred)
            plt.legend(['Cosmos ypred'])
        def CryptocomCoinPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XCryptocomCoin_train,YCryptocomCoin_train)
            ypred=model.predict(XCryptocomCoin_test)
            print(pd.DataFrame({'real_value':YCryptocomCoin_test,'pred_value':ypred}))
            print(model.score(XCryptocomCoin_test,YCryptocomCoin_test))
            plt.plot(ypred)
            plt.legend(['CrytocomCoin ypred'])
        def DogecoinPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XDogecoin_train,YDogecoin_train)
            ypred=model.predict(XDogecoin_test)
            print(pd.DataFrame({'real_value':YDogecoin_test,'pred_value':ypred}))
            print(model.score(XDogecoin_test,YDogecoin_test))
            plt.plot(ypred)
            plt.legend(['Dogecoin ypred'])
        def EOSPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XEOS_train,YEOS_train)
            ypred=model.predict(XEOS_test)
            print(pd.DataFrame({'real_value':YEOS_test,'pred_value':ypred}))
            print(model.score(XEOS_test,YEOS_test))
            plt.plot(ypred)
            plt.legend(['EOS ypred'])
        def EthereumPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XEthereum_train,YEthereum_train)
            ypred=model.predict(XEthereum_test)
            print(pd.DataFrame({'real_value':YEthereum_test,'pred_value':ypred}))
            print(model.score(XEthereum_test,YEthereum_test))
            plt.plot(ypred)
            plt.legend(['Ethereum ypred'])
        def IotaPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XIota_train,YIota_train)
            ypred=model.predict(XIota_test)
            print(pd.DataFrame({'real_value':YIota_test,'pred_value':ypred}))
            print(model.score(XIota_test,YIota_test))
            plt.plot(ypred)
            plt.legend(['Iota ypred'])
        def LitecoinPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XLitecoin_train,YLitecoin_train)
            ypred=model.predict(XLitecoin_test)
            print(pd.DataFrame({'real_value':YLitecoin_test,'pred_value':ypred}))
            print(model.score(XLitecoin_test,YLitecoin_test))
            plt.plot(ypred)
            plt.legend(['Litecoin ypred'])
        def MoneroPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XMonero_train,YMonero_train)
            ypred=model.predict(XMonero_test)
            print(pd.DataFrame({'real_value':YMonero_test,'pred_value':ypred}))
            print(model.score(XMonero_test,YMonero_test))
            plt.plot(ypred)
            plt.legend(['Monero ypred'])
        def NEMPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XNEM_train,YNEM_train)
            ypred=model.predict(XNEM_test)
            print(pd.DataFrame({'real_value':YNEM_test,'pred_value':ypred}))
            print(model.score(XNEM_test,YNEM_test))
            plt.plot(ypred)
            plt.legend(['NEM ypred'])
        def PolkadotPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XPolkadot_train,YPolkadot_train)
            ypred=model.predict(XPolkadot_test)
            print(pd.DataFrame({'real_value':YPolkadot_test,'pred_value':ypred}))
            print(model.score(XPolkadot_test,YPolkadot_test))
            plt.plot(ypred)
            plt.legend(['Polkadot ypred'])
        def SolanaPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XSolana_train,YSolana_train)
            ypred=model.predict(XSolana_test)
            print(pd.DataFrame({'real_value':YSolana_test,'pred_value':ypred}))
            print(model.score(XSolana_test,YSolana_test))
            plt.plot(ypred)
            plt.legend(['Solana ypred'])
        def StellarPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XStellar_train,YStellar_train)
            ypred=model.predict(XStellar_test)
            print(pd.DataFrame({'real_value':YStellar_test,'pred_value':ypred}))
            print(model.score(XStellar_test,YStellar_test))
            plt.plot(ypred)
            plt.legend(['Stellar ypred'])
        def TetherPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XTether_train,YTether_train)
            ypred=model.predict(XTether_test)
            print(pd.DataFrame({'real_value':YTether_test,'pred_value':ypred}))
            print(model.score(XTether_test,YTether_test))
            plt.plot(ypred)
            plt.legend(['Tether ypred'])
        def TronPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XTron_train,YTron_train)
            ypred=model.predict(XTron_test)
            print(pd.DataFrame({'real_value':YTron_test,'pred_value':ypred}))
            print(model.score(XTron_test,YTron_test))
            plt.plot(ypred)
            plt.legend(['Tron ypred'])
        def UniswapPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XUniswap_train,YUniswap_train)
            ypred=model.predict(XUniswap_test)
            print(pd.DataFrame({'real_value':YUniswap_test,'pred_value':ypred}))
            print(model.score(XUniswap_test,YUniswap_test))
            plt.plot(ypred)
            plt.legend(['Uniswap ypred'])
        def USDCoinPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XUSDCoin_train,YUSDCoin_train)
            ypred=model.predict(XUSDCoin_test)
            print(pd.DataFrame({'real_value':YUSDCoin_test,'pred_value':ypred}))
            print(model.score(XUSDCoin_test,YUSDCoin_test))
            plt.plot(ypred)
            plt.legend(['USDCoin ypred'])
        def WrappedBitcoinPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XWrappedBitcoin_train,YWrappedBitcoin_train)
            ypred=model.predict(XWrappedBitcoin_test)
            print(pd.DataFrame({'real_value':YWrappedBitcoin_test,'pred_value':ypred}))
            print(model.score(XWrappedBitcoin_test,YWrappedBitcoin_test))
            plt.plot(ypred)
            plt.legend(['WrappedBitcoin ypred'])
        def XRPPre():
            model=DecisionTreeRegressor(max_depth=1)
            model.fit(XXRP_train,YXRP_train)
            ypred=model.predict(XXRP_test)
            print(pd.DataFrame({'real_value':YXRP_test,'pred_value':ypred}))
            print(model.score(XXRP_test,YXRP_test))
            plt.plot(ypred)
            plt.legend(['XRP ypred'])
        def runAll():
            if __name__ == '__main__':
                plt.title('Model DecisionTreeRegressor Predict By MarketCap')
                Thread(AavePre()).start()
                # Thread(BinanceCoinPre()).start()
                # Thread(BitcoinPre()).start()
                # Thread(CardanoPre()).start()
                # Thread(ChainLinkPre()).start()
                # Thread(CosmosPre()).start()
                # Thread(CryptocomCoinPre()).start()
                # Thread(DogecoinPre()).start()
                # Thread(EOSPre()).start()                
                # Thread(EthereumPre()).start()
                # Thread(IotaPre()).start()
                # Thread(LitecoinPre()).start()
                # Thread(MoneroPre()).start()
                # Thread(NEMPre()).start()
                # Thread(PolkadotPre()).start()
                # Thread(SolanaPre()).start()
                # Thread(StellarPre()).start()
                # Thread(TetherPre()).start()
                # Thread(TronPre()).start()
                # Thread(UniswapPre()).start()
                # Thread(USDCoinPre()).start()
                # Thread(WrappedBitcoinPre()).start()
                # Thread(XRPPre()).start()
        runAll()

# %%
    def Neural_network(self):
        def process_model_train(data): #argument data read from run function
            sc = MinMaxScaler(feature_range = (0,1))
            train_test = len(data) - int(.2*len(data))
            train = data.iloc[:train_test]            
            test = data.iloc[train_test:]             
            datafilter = data.iloc[:,7:8].values
            train = train.iloc[:,7:8].values    
            test = test.iloc[:,7:8].values      
            data = np.reshape(datafilter,(-1,1))
            train  = np.reshape(train,(-1,1))    
            test = np.reshape(test,(-1,1))        
            sc.fit(data)                
            train = sc.transform(train) 
            test =sc.transform(test)    
            x = []
            y = []
            time = 30                    
            for i in range(time,len(train)): 
                x.append(train[i-time:i,0]) 
                y.append(train[i,0])        
            x, y = np.array(x),np.array(y)              
            x = np.reshape(x,(x.shape[0],x.shape[1],1))    
            model = Sequential()                                              
            model.add(LSTM(128,input_shape = (x.shape[1], x.shape[2])))      
            model.add(Dropout(.3))                                            
            model.add(Dense(1))                                                
            model.add(Activation('linear'))                                   
            model.compile(optimizer= 'adam',loss='mae')        
            history = model.fit(x, y, validation_split=.2, epochs=5, batch_size=32)         
            x=[]
            y=[]
            time=30
            for i in range(time,len(test)):         
                x.append(test[i-time:i,0])
                y.append(test[i,0])
            x,y = np.array(x),np.array(y)              
            x  = np.reshape(x,(x.shape[0],x.shape[1],1))
            pred = model.predict(x) 
            print(pred.shape)            
            result = model.evaluate(x,y)
            return result,pred,y
        def run():
            result ={}
            pred ={}
            actual ={}
            for i in paths:
                result[i],pred[i],actual[i] = process_model_train(data=pd.read_csv(i))             
            plt.figure(figsize=(15,15))
            for i in enumerate(paths):
                plt.subplot(7,4,i[0]+1)
                plt.plot(actual[i[1]],label='actual')
                plt.plot(pred[i[1]],label='predict')
                plt.legend(['actual','predict'])
        run()
