# %%
# %run ./Library.ipynb

# %% [markdown]
# # Setup csv file and dataframe

# %%
# symbol = ['BTCUSDT','ETHUSDT','BNBUSDT','XRPUSDT','ADAUSDT','SOLUSDT','AVAXUSDT','LUNAUSDT','DOTUSDT',
#           'DOGEUSDT','SHIBUSDT','MATICUSDT','LTCUSDT','ATOMUSDT','LINKUSDT','TRXUSDT','NEARUSDT','BCHUSDT',
#           'ALGOUSDT','FTTUSDT','XLMUSDT','FTMUSTD','UNIUSDT','HBARUSDT']
symbol = ['BTC/USDT']

# %%
postframe = pd.DataFrame(symbol)
postframe.columns = ['Currency']

# %%
postframe['Position'] = 0
postframe['quantity'] = 0

# %%
postframe.to_csv('positioncheck',index = False)
pd.read_csv('positioncheck')
# Out:
#      Currency  Position  quantity
# 0     BTCUSDT         0         0
# 1     ETHUSDT         0         0
# 2     BNBUSDT         0         0
# 3     XRPUSDT         0         0
# 4     ADAUSDT         0         0
# 5     SOLUSDT         0         0
# 6    AVAXUSDT         0         0
# 7    LUNAUSDT         0         0
# 8     DOTUSDT         0         0
# 9    DOGEUSDT         0         0
# 10   SHIBUSDT         0         0
# 11  MATICUSDT         0         0
# 12    LTCUSDT         0         0
# 13   ATOMUSDT         0         0
# 14   LINKUSDT         0         0
# 15    TRXUSDT         0         0
# 16   NEARUSDT         0         0
# 17    BCHUSDT         0         0
# 18   ALGOUSDT         0         0
# 19    FTTUSDT         0         0
# 20    XLMUSDT         0         0
# 21    FTMUSTD         0         0
# 22    UNIUSDT         0         0
# 23   HBARUSDT         0         0
